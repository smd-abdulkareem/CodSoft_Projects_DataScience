# %% [markdown]
# <a href="https://colab.research.google.com/github/smd-abdulkareem/CodSoft_Projects_DataScience/blob/main/IRIS_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris=pd.read_csv('IRIS.csv.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris[iris['sepal_width']>4]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa

# %%
iris['petal_width']>1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_width, Length: 150, dtype: bool

# %%
iris[iris['petal_width']>1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [93 rows x 5 columns]

# %%
iris[iris['petal_width']>2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris,hue='species')
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
y=iris[['sepal_length']]
x=iris[['sepal_width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train.head()
# Out:
#      sepal_width
# 17           3.5
# 42           3.2
# 97           2.9
# 125          3.2
# 106          2.5

# %%
x_test.head()
# Out:
#      sepal_width
# 53           2.3
# 93           2.3
# 84           3.0
# 2            3.2
# 114          2.8

# %%
y_train.head()
# Out:
#      sepal_length
# 17            5.1
# 42            4.4
# 97            6.2
# 125           7.2
# 106           4.9

# %%
y_test.head()
# Out:
#      sepal_length
# 53            5.5
# 93            5.0
# 84            5.4
# 2             4.7
# 114           5.8

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_test.head()
# Out:
#      sepal_length
# 53            5.5
# 93            5.0
# 84            5.4
# 2             4.7
# 114           5.8

# %%
y_pred[0:5]
# Out:
# array([[5.96643367],
#        [5.96643367],
#        [5.84269832],
#        [5.80734536],
#        [5.87805128]])

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.7448472696086761

# %%
r2=r2_score(y_test,y_pred)
print('r2 score for perfect model is',r2)
# Out:
# r2 score for perfect model is 0.016768975412916887

# %% [markdown]
# Model-2

# %%
y=iris[['sepal_length']]
x=iris[['sepal_width','petal_length','petal_width']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.09106405569618534

# %%
print(lr2.intercept_)
print(lr2.coef_)
# Out:
# [1.76429466]
# [[ 0.66059986  0.75346162 -0.64431246]]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print('r2 score for perfect model is',r2)
# Out:
# r2 score for perfect model is 0.8629837332376508
